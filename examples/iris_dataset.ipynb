# %% [markdown]
# # Iris Dataset Visualization

# %%
from pprint import pprint
from data_catalog import DataCatalog
import os
from dotenv import load_dotenv
load_dotenv();

# %%
api_key = 'LmHQ28ZzCUiMmKZ/vJE2ub+fzbO4JZ+HQdz6byAfyGQthG6mcRjsX9UNZq9GODdkJm/Tvib4/ONHzYo2AlI1QA=='
with DataCatalog(api_key=api_key) as service:
    results = service.list_assets()
    pprint([(asset.id, asset.name) for asset in results])
# Out:
# [('605c82b5a9c6491fc32a0ca7', 'Iris Dataset'),
#  ('605cada28fb013123ac33704', 'Iris Dataset'),
#  ('605dfaee61c84b474edb33bb', 'Iris Dataset'),
#  ('60684290a2abef6143e8e997', 'Iris Dataset'),
#  ('60687af04aa1ce43ff65520e', 'Stroke Prediction Dataset')]

# %% [markdown]
# ### Finding the asset

# %%
asset = service.get_asset('605c82b5a9c6491fc32a0ca7')

# %% [markdown]
#    ### Getting the data

# %%
dataframe = asset.get_data()
dataframe.columns = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class']

print(dataframe)
# Out:
#      sepal length  sepal width  petal length  petal width      class
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Visualization

# %%
import seaborn as sns

sns.displot(dataframe, kind='kde');
